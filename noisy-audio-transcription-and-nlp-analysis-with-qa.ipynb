# %%
# !pip install soundfile pydub SpeechRecognition transformers nltk matplotlib
# Out:
# Requirement already satisfied: soundfile in /usr/local/lib/python3.11/dist-packages (0.13.1)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (0.25.1)
# Collecting SpeechRecognition
#   Downloading speechrecognition-3.14.2-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.7.5)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile) (1.17.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from soundfile) (1.26.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from SpeechRecognition) (4.13.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->soundfile) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->soundfile) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->soundfile) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->soundfile) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->soundfile) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->soundfile) (2.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->soundfile) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->soundfile) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->soundfile) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->soundfile) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->soundfile) (2024.2.0)
# Downloading speechrecognition-3.14.2-py3-none-any.whl (32.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 57.8 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.14.2

# %%
# !apt-get install -y ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 122 not upgraded.

# %%
import os
import numpy as np
import soundfile as sf
import speech_recognition as sr
import pydub
from pydub import AudioSegment
import pandas as pd
import nltk
from transformers import pipeline

# %%
from pydub import AudioSegment
import numpy as np
import os

# Add noise function
def add_noise(audio_path, noise_level=0.02):
    # Load the clean audio
    audio = AudioSegment.from_file(audio_path)
    
    # Generate white noise: random values with the same length as the audio
    noise = np.random.normal(0, noise_level, len(audio.get_array_of_samples()))
    
    # Convert the noise into an AudioSegment
    noise_audio = AudioSegment(
        noise.tobytes(), 
        frame_rate=audio.frame_rate,
        sample_width=audio.sample_width, 
        channels=audio.channels
    )
    
    # Overlay noise onto the original audio
    noisy_audio = audio + noise_audio
    return noisy_audio

# Save the noisy audio
def save_noisy_audio(clean_audio_file, output_path):
    noisy_audio = add_noise(clean_audio_file)
    noisy_audio.export(output_path, format="wav")
    print(f"🔊 Noisy audio saved to {output_path}")

# Function to process all audio files in the directory
def process_all_audio_files(input_dir, output_dir, noise_level=0.02):
    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)
    
    # Loop through all files in the directory
    for filename in os.listdir(input_dir):
        if filename.endswith(".mp3") or filename.endswith(".wav"):
            clean_audio_path = os.path.join(input_dir, filename)
            noisy_audio_path = os.path.join(output_dir, f"noisy_{filename.replace('.mp3', '.wav').replace('.wav', '.wav')}")
            
            # Add noise and save
            save_noisy_audio(clean_audio_path, noisy_audio_path)

# Example usage to process all files inside the "Common Voice" directory
input_dir = "/kaggle/input/16000hzwav/16000Hz/103/1240"
output_dir = "/kaggle/working/noisy_audio_files"

process_all_audio_files(input_dir, output_dir)
# Out:
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0047_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0031_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0002_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0055_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0036_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0038_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0025_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0024_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0046_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0015_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0022_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0016_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0019_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0010_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0054_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0007_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0026_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0043_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0051_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0037_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0013_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0017_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0034_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0032_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0041_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0009_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0003_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0012_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0042_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0035_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0044_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0052_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0033_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0028_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0053_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0018_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0030_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0000_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0005_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0006_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0004_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0029_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0050_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0027_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0045_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0014_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0057_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0011_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0039_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0048_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0008_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0021_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0001_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0023_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0056_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0049_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0040_16000Hz.wav
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0020_16000Hz.wav

# %%
import os
import spacy
import speech_recognition as sr

# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

def transcribe_audio(audio_file):
    recognizer = sr.Recognizer()
    with sr.AudioFile(audio_file) as source:
        audio = recognizer.record(source)
        try:
            transcription = recognizer.recognize_google(audio)
            return transcription
        except sr.UnknownValueError:
            return ""
        except sr.RequestError:
            return ""

# spaCy processing function
def process_text_spacy(text):
    doc = nlp(text)
    tokens = [token.text for token in doc]
    pos_tags = [token.pos_ for token in doc]
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    return tokens, pos_tags, entities

# Main function to process only the first 3 audio files
def process_first_3_audio_files(input_dir, output_dir, noise_level=0.02):
    os.makedirs(output_dir, exist_ok=True)
    
    all_transcripts = []  # List to accumulate all transcriptions
    
    # Get only first 3 files
    all_files = [f for f in os.listdir(input_dir) if f.endswith(".mp3") or f.endswith(".wav")]
    first_3_files = all_files[:3]
    
    # Loop through first 3 files
    for filename in first_3_files:
        clean_audio_path = os.path.join(input_dir, filename)
        noisy_audio_path = os.path.join(output_dir, f"noisy_{filename.replace('.mp3', '.wav').replace('.wav', '.wav')}")
        
        
        
        # Transcribe the noisy audio
        transcript = transcribe_audio(noisy_audio_path)
        all_transcripts.append(transcript)  # Add the transcript to the list
        
        # Process text with spaCy
        tokens, pos_tags, entities = process_text_spacy(transcript)
        
        # Print results for the current file
        print(f"\nFile: {filename}")
        print(f"Tokens: {tokens}")
        print(f"POS Tags: {pos_tags}")
        print(f"Entities: {entities}")
    
    # Combine all transcriptions
    full_transcript = " ".join(all_transcripts)
    print("\nFull Transcription from the first 3 files:", full_transcript)
    return full_transcript

# Example usage
input_dir = "/kaggle/input/16000hzwav/16000Hz/103/1240"
output_dir = "/kaggle/working/noisy_audio_files"

full_transcript = process_first_3_audio_files(input_dir, output_dir)
# Out:
# File: 103-1240-0047_16000Hz.wav
# Tokens: ['and', 'I', 'know', 'another', 'case', 'where', 'an', 'adopted', 'boy', 'used', 'to', 'suck', 'the', 'eggs', 'they', 'could', "n't", 'break', 'him', 'of', 'it', 'if', 'you', 'had', 'asked', 'my', 'advice', 'in', 'the', 'matter', 'which', 'you', 'did', "n't", 'do', 'marilla', 'I', "'d", 'have', 'said', 'for', 'mercy', 'cig', 'not', 'to', 'think', 'of', 'such', 'a', 'thing', 'that', "'s", 'what', 'I', 'want', 'you', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google']
# POS Tags: ['CCONJ', 'PRON', 'VERB', 'DET', 'NOUN', 'SCONJ', 'DET', 'ADJ', 'NOUN', 'VERB', 'PART', 'VERB', 'DET', 'NOUN', 'PRON', 'AUX', 'PART', 'VERB', 'PRON', 'ADP', 'PRON', 'SCONJ', 'PRON', 'AUX', 'VERB', 'PRON', 'NOUN', 'ADP', 'DET', 'NOUN', 'PRON', 'PRON', 'AUX', 'PART', 'VERB', 'NOUN', 'PRON', 'AUX', 'AUX', 'VERB', 'ADP', 'NOUN', 'PROPN', 'PART', 'PART', 'VERB', 'ADP', 'DET', 'DET', 'NOUN', 'PRON', 'AUX', 'PRON', 'PRON', 'VERB', 'PRON', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN']
# Entities: [('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG')]
#
# File: 103-1240-0031_16000Hz.wav
# Tokens: ['but', 'there', 'was', 'a', 'saving', 'something', 'about', 'her', 'mouth', 'which', 'if', 'it', 'had', 'been', 'ever', 'so', 'slightly', 'developed', 'might', 'have', 'been', 'considered', 'indicative', 'of', 'a', 'sense', 'of', 'humour', 'we', "'re", 'all', 'pretty', 'well', 'said', 'Mrs', 'Rachel', 'I', 'was', 'kind', 'of', 'afraid', 'you', 'were', "n't", 'though', 'when', 'I', 'saw', 'Matthew', 'starting', 'off', 'today', 'I', 'thought', 'maybe', 'he', 'was', 'going', 'to', 'the', 'Doctor', 'Who', 'what', 'what']
# POS Tags: ['CCONJ', 'PRON', 'VERB', 'DET', 'VERB', 'PRON', 'ADP', 'PRON', 'NOUN', 'PRON', 'SCONJ', 'PRON', 'AUX', 'AUX', 'ADV', 'ADV', 'ADV', 'VERB', 'AUX', 'AUX', 'AUX', 'VERB', 'ADJ', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'PRON', 'AUX', 'ADV', 'ADV', 'ADV', 'VERB', 'PROPN', 'PROPN', 'PRON', 'AUX', 'ADV', 'ADV', 'ADJ', 'PRON', 'AUX', 'PART', 'SCONJ', 'SCONJ', 'PRON', 'VERB', 'PROPN', 'VERB', 'ADP', 'NOUN', 'PRON', 'VERB', 'ADV', 'PRON', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', 'PRON', 'PRON', 'PRON']
# Entities: [('Mrs Rachel', 'PERSON'), ('Matthew', 'PERSON'), ('today', 'DATE')]
#
# File: 103-1240-0002_16000Hz.wav
# Tokens: ['it', 'probably', 'was', 'conscious', 'that', 'Mrs', 'Rachel', 'was', 'sitting', 'at', 'her', 'window', 'keeping', 'a', 'sharp', 'eye', 'on', 'everything', 'that', 'passed', 'from', 'Brooks', 'and', 'children', 'up', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google', 'hey', 'Google']
# POS Tags: ['PRON', 'ADV', 'AUX', 'ADJ', 'SCONJ', 'PROPN', 'PROPN', 'AUX', 'VERB', 'ADP', 'PRON', 'NOUN', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'PRON', 'PRON', 'VERB', 'ADP', 'PROPN', 'CCONJ', 'NOUN', 'ADP', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN', 'INTJ', 'PROPN']
# Entities: [('Mrs Rachel', 'PERSON'), ('Brooks', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG'), ('Google', 'ORG')]
#
# Full Transcription from the first 3 files: and I know another case where an adopted boy used to suck the eggs they couldn't break him of it if you had asked my advice in the matter which you didn't do marilla I'd have said for mercy cig not to think of such a thing that's what I want you Google hey Google hey Google hey Google hey Google hey Google hey Google but there was a saving something about her mouth which if it had been ever so slightly developed might have been considered indicative of a sense of humour we're all pretty well said Mrs Rachel I was kind of afraid you weren't though when I saw Matthew starting off today I thought maybe he was going to the Doctor Who what what it probably was conscious that Mrs Rachel was sitting at her window keeping a sharp eye on everything that passed from Brooks and children up hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google hey Google

# %%
# Remove "hey Google" from the transcript
cleaned_transcript = full_transcript.replace("hey Google", "").strip()

# Print the cleaned transcription
print("\nCleaned Full Transcription from the first 3 files:\n", cleaned_transcript)
# Out:
# Cleaned Full Transcription from the first 3 files:
#  and I know another case where an adopted boy used to suck the eggs they couldn't break him of it if you had asked my advice in the matter which you didn't do marilla I'd have said for mercy cig not to think of such a thing that's what I want you Google       but there was a saving something about her mouth which if it had been ever so slightly developed might have been considered indicative of a sense of humour we're all pretty well said Mrs Rachel I was kind of afraid you weren't though when I saw Matthew starting off today I thought maybe he was going to the Doctor Who what what it probably was conscious that Mrs Rachel was sitting at her window keeping a sharp eye on everything that passed from Brooks and children up

# %%
import nltk
from transformers import pipeline

# Ensure you have nltk tokenization tools downloaded
nltk.download('punkt')

# KWIC Analysis Function
def kwic_analysis(text, keyword):
    words = nltk.word_tokenize(text)  # Tokenize the entire text
    indices = [i for i, word in enumerate(words) if word.lower() == keyword.lower()]
    
    # Create context by looking at 5 words before and after the keyword
    context = [(words[max(i-5, 0):i+6], words[i]) for i in indices]
    
    # Print the context of the keyword in the text
    for c in context:
        print(f"Context: {c[0]}, Keyword: {c[1]}")
    
    return context
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Question Answering Function
def answer_question(transcript, question, qa_pipeline):
    # Use the QA pipeline to answer a question based on the provided transcript
    result = qa_pipeline(question=question, context=transcript)
    print(f"Answer: {result['answer']}")
    return result['answer']

# Example keyword for KWIC analysis
kwic_context = kwic_analysis(full_transcript, "speech")

# Example QA pipeline for question answering (ensure you have a QA model loaded)
qa_pipeline = pipeline("question-answering", model="distilbert-base-uncased-distilled-squad")

# Example question for answering
answer = answer_question(full_transcript, "Where is Mrs Rachel Sitting?", qa_pipeline)
# Out:
# Device set to use cuda:0
# Answer: at her window

# %%
# Check the full transcript
print(f"Full Transcript: {full_transcript[:5000]}...")  # Show the first 500 characters

# Run the QA pipeline on the full transcript
answer = answer_question(full_transcript, "What is the main topic of the transcript?", qa_pipeline)
# Out:
# Full Transcript: Your combined transcription from all files goes here...
# Answer: Your combined transcription from all files

# %%
import os

def save_results(transcript, kwic_context, answer, file_name):
    results_dir = "/kaggle/working/results"
    
    # Ensure the results directory exists
    os.makedirs(results_dir, exist_ok=True)
    
    # Save the transcript to a file
    with open(f"{results_dir}/{file_name}_transcript.txt", "w") as f:
        f.write(transcript)
    
    # Save the KWIC context to a file
    with open(f"{results_dir}/{file_name}_kwic.txt", "w") as f:
        for context in kwic_context:
            f.write(f"Context: {context[0]}, Keyword: {context[1]}\n")
    
    # Save the answer to a file
    with open(f"{results_dir}/{file_name}_answer.txt", "w") as f:
        f.write(f"Answer: {answer}")

    print(f"Results saved for {file_name}.")
save_results(full_transcript, kwic_context, answer, "noisy_audio_file_name")
# Out:
# Results saved for noisy_audio_file_name.

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
def process_all_audio_files(input_dir, output_dir, noise_level=0.02):
    os.makedirs(output_dir, exist_ok=True)
    
    all_transcripts = []  # List to accumulate all transcriptions
    
    # Loop through all files in the directory
    for filename in os.listdir(input_dir):
        if filename.endswith(".mp3") or filename.endswith(".wav"):
            clean_audio_path = os.path.join(input_dir, filename)
            noisy_audio_path = os.path.join(output_dir, f"noisy_{filename.replace('.mp3', '.wav').replace('.wav', '.wav')}")
            
            # Add noise and save noisy audio
            save_noisy_audio(clean_audio_path, noisy_audio_path)
            
            # Transcribe the noisy audio
            transcript = transcribe_audio(noisy_audio_path)
            all_transcripts.append(transcript)  # Add the transcript to the list
            
            # Process text with spaCy
            tokens, pos_tags, entities = process_text_spacy(transcript)
            
            # Print results for the current file
            print(f"Tokens for {filename}:", tokens)
            print(f"POS Tags for {filename}:", pos_tags)
            print(f"Entities for {filename}:", entities)
    
    # After processing all files, combine all transcriptions
    full_transcript = " ".join(all_transcripts)
    print("Full Transcription from all files:", full_transcript)

# Example usage
input_dir = "/kaggle/input/16000hzwav/16000Hz/103/1240"
output_dir = "/kaggle/working/noisy_audio_files"

process_all_audio_files(input_dir, output_dir)
# Out:
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0047_16000Hz.wav
# Transcription: they couldn't break him of it if you had asked my advice in the matter which you didn't do Marilla I'd have said for Mercy sick not to think of such a thing that's what
# Tokens for 103-1240-0047_16000Hz.wav: ['they', 'could', "n't", 'break', 'him', 'of', 'it', 'if', 'you', 'had', 'asked', 'my', 'advice', 'in', 'the', 'matter', 'which', 'you', 'did', "n't", 'do', 'Marilla', 'I', "'d", 'have', 'said', 'for', 'Mercy', 'sick', 'not', 'to', 'think', 'of', 'such', 'a', 'thing', 'that', "'s", 'what']
# POS Tags for 103-1240-0047_16000Hz.wav: [('they', 'PRON'), ('could', 'AUX'), ("n't", 'PART'), ('break', 'VERB'), ('him', 'PRON'), ('of', 'ADP'), ('it', 'PRON'), ('if', 'SCONJ'), ('you', 'PRON'), ('had', 'AUX'), ('asked', 'VERB'), ('my', 'PRON'), ('advice', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('matter', 'NOUN'), ('which', 'PRON'), ('you', 'PRON'), ('did', 'AUX'), ("n't", 'PART'), ('do', 'VERB'), ('Marilla', 'PROPN'), ('I', 'PRON'), ("'d", 'AUX'), ('have', 'AUX'), ('said', 'VERB'), ('for', 'ADP'), ('Mercy', 'PROPN'), ('sick', 'ADJ'), ('not', 'PART'), ('to', 'PART'), ('think', 'VERB'), ('of', 'ADP'), ('such', 'DET'), ('a', 'DET'), ('thing', 'NOUN'), ('that', 'PRON'), ("'s", 'AUX'), ('what', 'PRON')]
# Entities for 103-1240-0047_16000Hz.wav: []
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0031_16000Hz.wav
# Transcription: but there was a saving something about her mouth which if it had been ever so slightly developed might have been considered indicative of a sense of humor we're all pretty well said Mrs Rachel I was kind of afraid you weren't though when I saw Matthew starting off today I thought maybe he was going to the doctors
# Tokens for 103-1240-0031_16000Hz.wav: ['but', 'there', 'was', 'a', 'saving', 'something', 'about', 'her', 'mouth', 'which', 'if', 'it', 'had', 'been', 'ever', 'so', 'slightly', 'developed', 'might', 'have', 'been', 'considered', 'indicative', 'of', 'a', 'sense', 'of', 'humor', 'we', "'re", 'all', 'pretty', 'well', 'said', 'Mrs', 'Rachel', 'I', 'was', 'kind', 'of', 'afraid', 'you', 'were', "n't", 'though', 'when', 'I', 'saw', 'Matthew', 'starting', 'off', 'today', 'I', 'thought', 'maybe', 'he', 'was', 'going', 'to', 'the', 'doctors']
# POS Tags for 103-1240-0031_16000Hz.wav: [('but', 'CCONJ'), ('there', 'PRON'), ('was', 'VERB'), ('a', 'DET'), ('saving', 'VERB'), ('something', 'PRON'), ('about', 'ADP'), ('her', 'PRON'), ('mouth', 'NOUN'), ('which', 'PRON'), ('if', 'SCONJ'), ('it', 'PRON'), ('had', 'AUX'), ('been', 'AUX'), ('ever', 'ADV'), ('so', 'ADV'), ('slightly', 'ADV'), ('developed', 'VERB'), ('might', 'AUX'), ('have', 'AUX'), ('been', 'AUX'), ('considered', 'VERB'), ('indicative', 'ADJ'), ('of', 'ADP'), ('a', 'DET'), ('sense', 'NOUN'), ('of', 'ADP'), ('humor', 'NOUN'), ('we', 'PRON'), ("'re", 'AUX'), ('all', 'ADV'), ('pretty', 'ADV'), ('well', 'ADV'), ('said', 'VERB'), ('Mrs', 'PROPN'), ('Rachel', 'PROPN'), ('I', 'PRON'), ('was', 'AUX'), ('kind', 'ADV'), ('of', 'ADV'), ('afraid', 'ADJ'), ('you', 'PRON'), ('were', 'AUX'), ("n't", 'PART'), ('though', 'SCONJ'), ('when', 'SCONJ'), ('I', 'PRON'), ('saw', 'VERB'), ('Matthew', 'PROPN'), ('starting', 'VERB'), ('off', 'ADP'), ('today', 'NOUN'), ('I', 'PRON'), ('thought', 'VERB'), ('maybe', 'ADV'), ('he', 'PRON'), ('was', 'AUX'), ('going', 'VERB'), ('to', 'ADP'), ('the', 'DET'), ('doctors', 'NOUN')]
# Entities for 103-1240-0031_16000Hz.wav: [('Mrs Rachel', 'PERSON'), ('Matthew', 'PERSON'), ('today', 'DATE')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0002_16000Hz.wav
# Transcription: for not even a Brooke could run past Mrs Rachel Lynn's door without due regard for decency and decorum it probably was conscious that Mrs Rachel was sitting at her window keeping a sharp eye on everything that passed from Brooks and children up at
# Tokens for 103-1240-0002_16000Hz.wav: ['for', 'not', 'even', 'a', 'Brooke', 'could', 'run', 'past', 'Mrs', 'Rachel', 'Lynn', "'s", 'door', 'without', 'due', 'regard', 'for', 'decency', 'and', 'decorum', 'it', 'probably', 'was', 'conscious', 'that', 'Mrs', 'Rachel', 'was', 'sitting', 'at', 'her', 'window', 'keeping', 'a', 'sharp', 'eye', 'on', 'everything', 'that', 'passed', 'from', 'Brooks', 'and', 'children', 'up', 'at']
# POS Tags for 103-1240-0002_16000Hz.wav: [('for', 'ADP'), ('not', 'PART'), ('even', 'ADV'), ('a', 'DET'), ('Brooke', 'PROPN'), ('could', 'AUX'), ('run', 'VERB'), ('past', 'ADP'), ('Mrs', 'PROPN'), ('Rachel', 'PROPN'), ('Lynn', 'PROPN'), ("'s", 'PART'), ('door', 'NOUN'), ('without', 'ADP'), ('due', 'ADJ'), ('regard', 'NOUN'), ('for', 'ADP'), ('decency', 'NOUN'), ('and', 'CCONJ'), ('decorum', 'NOUN'), ('it', 'PRON'), ('probably', 'ADV'), ('was', 'AUX'), ('conscious', 'ADJ'), ('that', 'SCONJ'), ('Mrs', 'PROPN'), ('Rachel', 'PROPN'), ('was', 'AUX'), ('sitting', 'VERB'), ('at', 'ADP'), ('her', 'PRON'), ('window', 'NOUN'), ('keeping', 'VERB'), ('a', 'DET'), ('sharp', 'ADJ'), ('eye', 'NOUN'), ('on', 'ADP'), ('everything', 'PRON'), ('that', 'PRON'), ('passed', 'VERB'), ('from', 'ADP'), ('Brooks', 'PROPN'), ('and', 'CCONJ'), ('children', 'NOUN'), ('up', 'ADP'), ('at', 'ADP')]
# Entities for 103-1240-0002_16000Hz.wav: [('Brooke', 'PERSON'), ("Mrs Rachel Lynn's", 'PERSON'), ('Mrs Rachel', 'PERSON'), ('Brooks', 'ORG')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0055_16000Hz.wav
# Transcription: it does really seem as if I must be dreaming while I'm sorry for that poor young one and no mistake Matthew and Marilla don't know anything about children and they'll expect him to be wiser and steadier than his own grandfather what are
# Tokens for 103-1240-0055_16000Hz.wav: ['it', 'does', 'really', 'seem', 'as', 'if', 'I', 'must', 'be', 'dreaming', 'while', 'I', "'m", 'sorry', 'for', 'that', 'poor', 'young', 'one', 'and', 'no', 'mistake', 'Matthew', 'and', 'Marilla', 'do', "n't", 'know', 'anything', 'about', 'children', 'and', 'they', "'ll", 'expect', 'him', 'to', 'be', 'wiser', 'and', 'steadier', 'than', 'his', 'own', 'grandfather', 'what', 'are']
# POS Tags for 103-1240-0055_16000Hz.wav: [('it', 'PRON'), ('does', 'AUX'), ('really', 'ADV'), ('seem', 'VERB'), ('as', 'SCONJ'), ('if', 'SCONJ'), ('I', 'PRON'), ('must', 'AUX'), ('be', 'AUX'), ('dreaming', 'VERB'), ('while', 'SCONJ'), ('I', 'PRON'), ("'m", 'AUX'), ('sorry', 'ADJ'), ('for', 'ADP'), ('that', 'DET'), ('poor', 'ADJ'), ('young', 'ADJ'), ('one', 'NUM'), ('and', 'CCONJ'), ('no', 'DET'), ('mistake', 'NOUN'), ('Matthew', 'PROPN'), ('and', 'CCONJ'), ('Marilla', 'PROPN'), ('do', 'AUX'), ("n't", 'PART'), ('know', 'VERB'), ('anything', 'PRON'), ('about', 'ADP'), ('children', 'NOUN'), ('and', 'CCONJ'), ('they', 'PRON'), ("'ll", 'AUX'), ('expect', 'VERB'), ('him', 'PRON'), ('to', 'PART'), ('be', 'AUX'), ('wiser', 'ADJ'), ('and', 'CCONJ'), ('steadier', 'ADJ'), ('than', 'ADP'), ('his', 'PRON'), ('own', 'ADJ'), ('grandfather', 'NOUN'), ('what', 'PRON'), ('are', 'AUX')]
# Entities for 103-1240-0055_16000Hz.wav: [('Matthew', 'PERSON'), ('Marilla', 'PERSON')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0036_16000Hz.wav
# Transcription: marula and Matthew Cuthbert of all people adopting a boy from an orphan Asylum well the world was certainly turning upside down she would be surprised at nothing after this nothing at
# Tokens for 103-1240-0036_16000Hz.wav: ['marula', 'and', 'Matthew', 'Cuthbert', 'of', 'all', 'people', 'adopting', 'a', 'boy', 'from', 'an', 'orphan', 'Asylum', 'well', 'the', 'world', 'was', 'certainly', 'turning', 'upside', 'down', 'she', 'would', 'be', 'surprised', 'at', 'nothing', 'after', 'this', 'nothing', 'at']
# POS Tags for 103-1240-0036_16000Hz.wav: [('marula', 'PROPN'), ('and', 'CCONJ'), ('Matthew', 'PROPN'), ('Cuthbert', 'PROPN'), ('of', 'ADP'), ('all', 'DET'), ('people', 'NOUN'), ('adopting', 'VERB'), ('a', 'DET'), ('boy', 'NOUN'), ('from', 'ADP'), ('an', 'DET'), ('orphan', 'NOUN'), ('Asylum', 'PROPN'), ('well', 'ADV'), ('the', 'DET'), ('world', 'NOUN'), ('was', 'AUX'), ('certainly', 'ADV'), ('turning', 'VERB'), ('upside', 'ADV'), ('down', 'ADV'), ('she', 'PRON'), ('would', 'AUX'), ('be', 'AUX'), ('surprised', 'ADJ'), ('at', 'ADP'), ('nothing', 'PRON'), ('after', 'ADP'), ('this', 'DET'), ('nothing', 'PRON'), ('at', 'ADP')]
# Entities for 103-1240-0036_16000Hz.wav: [('Matthew Cuthbert', 'PERSON')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0038_16000Hz.wav
# Transcription: Mrs Alexander Spencer was up here one day before Christmas and she said she was going to get a little girl from the Asylum over in hopeton in the spring
# Tokens for 103-1240-0038_16000Hz.wav: ['Mrs', 'Alexander', 'Spencer', 'was', 'up', 'here', 'one', 'day', 'before', 'Christmas', 'and', 'she', 'said', 'she', 'was', 'going', 'to', 'get', 'a', 'little', 'girl', 'from', 'the', 'Asylum', 'over', 'in', 'hopeton', 'in', 'the', 'spring']
# POS Tags for 103-1240-0038_16000Hz.wav: [('Mrs', 'PROPN'), ('Alexander', 'PROPN'), ('Spencer', 'PROPN'), ('was', 'AUX'), ('up', 'ADV'), ('here', 'ADV'), ('one', 'NUM'), ('day', 'NOUN'), ('before', 'ADP'), ('Christmas', 'PROPN'), ('and', 'CCONJ'), ('she', 'PRON'), ('said', 'VERB'), ('she', 'PRON'), ('was', 'AUX'), ('going', 'VERB'), ('to', 'PART'), ('get', 'VERB'), ('a', 'DET'), ('little', 'ADJ'), ('girl', 'NOUN'), ('from', 'ADP'), ('the', 'DET'), ('Asylum', 'PROPN'), ('over', 'ADP'), ('in', 'ADP'), ('hopeton', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('spring', 'NOUN')]
# Entities for 103-1240-0038_16000Hz.wav: [('Mrs Alexander Spencer', 'PERSON'), ('one day before Christmas', 'DATE'), ('Asylum', 'ORG'), ('hopeton', 'GPE')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0025_16000Hz.wav
# Transcription: once you got a glimpse of the bloom white cherry trees in the left Orchard and nodding slender Birches down in the hollow by the Brook was screened over by a tangle of vines here satire Cuthbert when she sat at all always slightly distrustful of sunshine at what time are you going
# Tokens for 103-1240-0025_16000Hz.wav: ['once', 'you', 'got', 'a', 'glimpse', 'of', 'the', 'bloom', 'white', 'cherry', 'trees', 'in', 'the', 'left', 'Orchard', 'and', 'nodding', 'slender', 'Birches', 'down', 'in', 'the', 'hollow', 'by', 'the', 'Brook', 'was', 'screened', 'over', 'by', 'a', 'tangle', 'of', 'vines', 'here', 'satire', 'Cuthbert', 'when', 'she', 'sat', 'at', 'all', 'always', 'slightly', 'distrustful', 'of', 'sunshine', 'at', 'what', 'time', 'are', 'you', 'going']
# POS Tags for 103-1240-0025_16000Hz.wav: [('once', 'SCONJ'), ('you', 'PRON'), ('got', 'VERB'), ('a', 'DET'), ('glimpse', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('bloom', 'NOUN'), ('white', 'ADJ'), ('cherry', 'NOUN'), ('trees', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('left', 'ADJ'), ('Orchard', 'PROPN'), ('and', 'CCONJ'), ('nodding', 'NOUN'), ('slender', 'NOUN'), ('Birches', 'NOUN'), ('down', 'ADP'), ('in', 'ADP'), ('the', 'DET'), ('hollow', 'NOUN'), ('by', 'ADP'), ('the', 'DET'), ('Brook', 'PROPN'), ('was', 'AUX'), ('screened', 'VERB'), ('over', 'ADP'), ('by', 'ADP'), ('a', 'DET'), ('tangle', 'NOUN'), ('of', 'ADP'), ('vines', 'NOUN'), ('here', 'ADV'), ('satire', 'VERB'), ('Cuthbert', 'PROPN'), ('when', 'SCONJ'), ('she', 'PRON'), ('sat', 'VERB'), ('at', 'ADV'), ('all', 'ADV'), ('always', 'ADV'), ('slightly', 'ADV'), ('distrustful', 'ADJ'), ('of', 'ADP'), ('sunshine', 'NOUN'), ('at', 'ADP'), ('what', 'DET'), ('time', 'NOUN'), ('are', 'AUX'), ('you', 'PRON'), ('going', 'VERB')]
# Entities for 103-1240-0025_16000Hz.wav: [('Orchard', 'PERSON'), ('Birches', 'PERSON'), ('Brook', 'ORG'), ('Cuthbert', 'PERSON')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0024_16000Hz.wav
# Transcription: or would have been cheerful if it did not been so painfully clean as to give it something of the appearance of an unused parlor its Windows looked east and west through the West one looking out on the backyard came a flood of mellow June sunlight but the East one goes up at
# Tokens for 103-1240-0024_16000Hz.wav: ['or', 'would', 'have', 'been', 'cheerful', 'if', 'it', 'did', 'not', 'been', 'so', 'painfully', 'clean', 'as', 'to', 'give', 'it', 'something', 'of', 'the', 'appearance', 'of', 'an', 'unused', 'parlor', 'its', 'Windows', 'looked', 'east', 'and', 'west', 'through', 'the', 'West', 'one', 'looking', 'out', 'on', 'the', 'backyard', 'came', 'a', 'flood', 'of', 'mellow', 'June', 'sunlight', 'but', 'the', 'East', 'one', 'goes', 'up', 'at']
# POS Tags for 103-1240-0024_16000Hz.wav: [('or', 'CCONJ'), ('would', 'AUX'), ('have', 'AUX'), ('been', 'AUX'), ('cheerful', 'ADJ'), ('if', 'SCONJ'), ('it', 'PRON'), ('did', 'AUX'), ('not', 'PART'), ('been', 'AUX'), ('so', 'ADV'), ('painfully', 'ADV'), ('clean', 'ADJ'), ('as', 'SCONJ'), ('to', 'PART'), ('give', 'VERB'), ('it', 'PRON'), ('something', 'PRON'), ('of', 'ADP'), ('the', 'DET'), ('appearance', 'NOUN'), ('of', 'ADP'), ('an', 'DET'), ('unused', 'ADJ'), ('parlor', 'NOUN'), ('its', 'PRON'), ('Windows', 'PROPN'), ('looked', 'VERB'), ('east', 'NOUN'), ('and', 'CCONJ'), ('west', 'NOUN'), ('through', 'ADP'), ('the', 'DET'), ('West', 'PROPN'), ('one', 'NUM'), ('looking', 'VERB'), ('out', 'ADP'), ('on', 'ADP'), ('the', 'DET'), ('backyard', 'NOUN'), ('came', 'VERB'), ('a', 'DET'), ('flood', 'NOUN'), ('of', 'ADP'), ('mellow', 'ADJ'), ('June', 'PROPN'), ('sunlight', 'NOUN'), ('but', 'CCONJ'), ('the', 'DET'), ('East', 'PROPN'), ('one', 'NOUN'), ('goes', 'VERB'), ('up', 'ADP'), ('at', 'ADP')]
# Entities for 103-1240-0024_16000Hz.wav: [('Windows', 'NORP'), ('June', 'DATE')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0046_16000Hz.wav
# Transcription: why it was only last week I read in the paper how a man and his wife up west of the island took a boy out of an orphan Asylum and he said fire to the house at night set it on purpose marila and nearly burned them to a crisp in their beds at
# Tokens for 103-1240-0046_16000Hz.wav: ['why', 'it', 'was', 'only', 'last', 'week', 'I', 'read', 'in', 'the', 'paper', 'how', 'a', 'man', 'and', 'his', 'wife', 'up', 'west', 'of', 'the', 'island', 'took', 'a', 'boy', 'out', 'of', 'an', 'orphan', 'Asylum', 'and', 'he', 'said', 'fire', 'to', 'the', 'house', 'at', 'night', 'set', 'it', 'on', 'purpose', 'marila', 'and', 'nearly', 'burned', 'them', 'to', 'a', 'crisp', 'in', 'their', 'beds', 'at']
# POS Tags for 103-1240-0046_16000Hz.wav: [('why', 'SCONJ'), ('it', 'PRON'), ('was', 'AUX'), ('only', 'ADV'), ('last', 'ADJ'), ('week', 'NOUN'), ('I', 'PRON'), ('read', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('paper', 'NOUN'), ('how', 'SCONJ'), ('a', 'DET'), ('man', 'NOUN'), ('and', 'CCONJ'), ('his', 'PRON'), ('wife', 'NOUN'), ('up', 'ADV'), ('west', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('island', 'NOUN'), ('took', 'VERB'), ('a', 'DET'), ('boy', 'NOUN'), ('out', 'ADP'), ('of', 'ADP'), ('an', 'DET'), ('orphan', 'NOUN'), ('Asylum', 'PROPN'), ('and', 'CCONJ'), ('he', 'PRON'), ('said', 'VERB'), ('fire', 'NOUN'), ('to', 'ADP'), ('the', 'DET'), ('house', 'NOUN'), ('at', 'ADP'), ('night', 'NOUN'), ('set', 'VERB'), ('it', 'PRON'), ('on', 'ADP'), ('purpose', 'NOUN'), ('marila', 'PROPN'), ('and', 'CCONJ'), ('nearly', 'ADV'), ('burned', 'VERB'), ('them', 'PRON'), ('to', 'ADP'), ('a', 'DET'), ('crisp', 'NOUN'), ('in', 'ADP'), ('their', 'PRON'), ('beds', 'NOUN'), ('at', 'ADP')]
# Entities for 103-1240-0046_16000Hz.wav: [('only last week', 'DATE'), ('night', 'TIME')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0015_16000Hz.wav
# Transcription: if you run out of turnip seed he wouldn't dress up and take the buggy to go for more reasons
# Tokens for 103-1240-0015_16000Hz.wav: ['if', 'you', 'run', 'out', 'of', 'turnip', 'seed', 'he', 'would', "n't", 'dress', 'up', 'and', 'take', 'the', 'buggy', 'to', 'go', 'for', 'more', 'reasons']
# POS Tags for 103-1240-0015_16000Hz.wav: [('if', 'SCONJ'), ('you', 'PRON'), ('run', 'VERB'), ('out', 'ADP'), ('of', 'ADP'), ('turnip', 'NOUN'), ('seed', 'NOUN'), ('he', 'PRON'), ('would', 'AUX'), ("n't", 'PART'), ('dress', 'VERB'), ('up', 'ADP'), ('and', 'CCONJ'), ('take', 'VERB'), ('the', 'DET'), ('buggy', 'NOUN'), ('to', 'PART'), ('go', 'VERB'), ('for', 'ADP'), ('more', 'ADJ'), ('reasons', 'NOUN')]
# Entities for 103-1240-0015_16000Hz.wav: []
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0022_16000Hz.wav
# Transcription: set about on one side with great patriarchal Willows and the other with primates not a stray stick nor Stone was to be seen for Mrs Rachel would have seen it if there had been privately she was of the opinion that Marilla Cuthbert swept that yard over as often as she swept her house what
# Tokens for 103-1240-0022_16000Hz.wav: ['set', 'about', 'on', 'one', 'side', 'with', 'great', 'patriarchal', 'Willows', 'and', 'the', 'other', 'with', 'primates', 'not', 'a', 'stray', 'stick', 'nor', 'Stone', 'was', 'to', 'be', 'seen', 'for', 'Mrs', 'Rachel', 'would', 'have', 'seen', 'it', 'if', 'there', 'had', 'been', 'privately', 'she', 'was', 'of', 'the', 'opinion', 'that', 'Marilla', 'Cuthbert', 'swept', 'that', 'yard', 'over', 'as', 'often', 'as', 'she', 'swept', 'her', 'house', 'what']
# POS Tags for 103-1240-0022_16000Hz.wav: [('set', 'VERB'), ('about', 'ADP'), ('on', 'ADP'), ('one', 'NUM'), ('side', 'NOUN'), ('with', 'ADP'), ('great', 'ADJ'), ('patriarchal', 'ADJ'), ('Willows', 'PROPN'), ('and', 'CCONJ'), ('the', 'DET'), ('other', 'ADJ'), ('with', 'ADP'), ('primates', 'NOUN'), ('not', 'PART'), ('a', 'DET'), ('stray', 'ADJ'), ('stick', 'NOUN'), ('nor', 'CCONJ'), ('Stone', 'PROPN'), ('was', 'AUX'), ('to', 'PART'), ('be', 'AUX'), ('seen', 'VERB'), ('for', 'ADP'), ('Mrs', 'PROPN'), ('Rachel', 'PROPN'), ('would', 'AUX'), ('have', 'AUX'), ('seen', 'VERB'), ('it', 'PRON'), ('if', 'SCONJ'), ('there', 'PRON'), ('had', 'AUX'), ('been', 'AUX'), ('privately', 'ADV'), ('she', 'PRON'), ('was', 'AUX'), ('of', 'ADP'), ('the', 'DET'), ('opinion', 'NOUN'), ('that', 'SCONJ'), ('Marilla', 'PROPN'), ('Cuthbert', 'PROPN'), ('swept', 'VERB'), ('that', 'DET'), ('yard', 'NOUN'), ('over', 'ADP'), ('as', 'ADV'), ('often', 'ADV'), ('as', 'SCONJ'), ('she', 'PRON'), ('swept', 'VERB'), ('her', 'PRON'), ('house', 'NOUN'), ('what', 'PRON')]
# Entities for 103-1240-0022_16000Hz.wav: [('Willows', 'PRODUCT'), ('Stone', 'ORG'), ('Mrs Rachel', 'PERSON'), ('Marilla Cuthbert', 'PERSON')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0016_16000Hz.wav
# Transcription: get something must have happened since last night to start him off I'm clean puzzle that's what and I won't know a minute's peace of mind or conscience until I know what has taken Matthew Cuthbert out of heavenly today accordingly after tea Mrs Rachel set out she had not far to go to
# Tokens for 103-1240-0016_16000Hz.wav: ['get', 'something', 'must', 'have', 'happened', 'since', 'last', 'night', 'to', 'start', 'him', 'off', 'I', "'m", 'clean', 'puzzle', 'that', "'s", 'what', 'and', 'I', 'wo', "n't", 'know', 'a', 'minute', "'s", 'peace', 'of', 'mind', 'or', 'conscience', 'until', 'I', 'know', 'what', 'has', 'taken', 'Matthew', 'Cuthbert', 'out', 'of', 'heavenly', 'today', 'accordingly', 'after', 'tea', 'Mrs', 'Rachel', 'set', 'out', 'she', 'had', 'not', 'far', 'to', 'go', 'to']
# POS Tags for 103-1240-0016_16000Hz.wav: [('get', 'VERB'), ('something', 'PRON'), ('must', 'AUX'), ('have', 'AUX'), ('happened', 'VERB'), ('since', 'SCONJ'), ('last', 'ADJ'), ('night', 'NOUN'), ('to', 'PART'), ('start', 'VERB'), ('him', 'PRON'), ('off', 'ADP'), ('I', 'PRON'), ("'m", 'AUX'), ('clean', 'ADJ'), ('puzzle', 'NOUN'), ('that', 'PRON'), ("'s", 'AUX'), ('what', 'PRON'), ('and', 'CCONJ'), ('I', 'PRON'), ('wo', 'AUX'), ("n't", 'PART'), ('know', 'VERB'), ('a', 'DET'), ('minute', 'NOUN'), ("'s", 'PART'), ('peace', 'NOUN'), ('of', 'ADP'), ('mind', 'NOUN'), ('or', 'CCONJ'), ('conscience', 'NOUN'), ('until', 'SCONJ'), ('I', 'PRON'), ('know', 'VERB'), ('what', 'PRON'), ('has', 'AUX'), ('taken', 'VERB'), ('Matthew', 'PROPN'), ('Cuthbert', 'PROPN'), ('out', 'ADP'), ('of', 'ADP'), ('heavenly', 'ADJ'), ('today', 'NOUN'), ('accordingly', 'ADV'), ('after', 'SCONJ'), ('tea', 'NOUN'), ('Mrs', 'PROPN'), ('Rachel', 'PROPN'), ('set', 'VERB'), ('out', 'ADP'), ('she', 'PRON'), ('had', 'AUX'), ('not', 'PART'), ('far', 'ADV'), ('to', 'PART'), ('go', 'VERB'), ('to', 'ADP')]
# Entities for 103-1240-0016_16000Hz.wav: [('last night', 'TIME'), ('Matthew Cuthbert', 'PERSON'), ('today', 'DATE'), ('Mrs Rachel', 'PERSON')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0019_16000Hz.wav
# Transcription: barely visible from the main road along which all the other avonley houses were so socially situated Mrs Rachel Lynde did not call living in such a place living at all it's just staying that's what she said if she stepped along the Deep rutted grassy Lane at
# Tokens for 103-1240-0019_16000Hz.wav: ['barely', 'visible', 'from', 'the', 'main', 'road', 'along', 'which', 'all', 'the', 'other', 'avonley', 'houses', 'were', 'so', 'socially', 'situated', 'Mrs', 'Rachel', 'Lynde', 'did', 'not', 'call', 'living', 'in', 'such', 'a', 'place', 'living', 'at', 'all', 'it', "'s", 'just', 'staying', 'that', "'s", 'what', 'she', 'said', 'if', 'she', 'stepped', 'along', 'the', 'Deep', 'rutted', 'grassy', 'Lane', 'at']
# POS Tags for 103-1240-0019_16000Hz.wav: [('barely', 'ADV'), ('visible', 'ADJ'), ('from', 'ADP'), ('the', 'DET'), ('main', 'ADJ'), ('road', 'NOUN'), ('along', 'ADP'), ('which', 'PRON'), ('all', 'DET'), ('the', 'DET'), ('other', 'ADJ'), ('avonley', 'ADJ'), ('houses', 'NOUN'), ('were', 'AUX'), ('so', 'ADV'), ('socially', 'ADV'), ('situated', 'VERB'), ('Mrs', 'PROPN'), ('Rachel', 'PROPN'), ('Lynde', 'PROPN'), ('did', 'AUX'), ('not', 'PART'), ('call', 'VERB'), ('living', 'VERB'), ('in', 'ADP'), ('such', 'DET'), ('a', 'DET'), ('place', 'NOUN'), ('living', 'VERB'), ('at', 'ADP'), ('all', 'ADV'), ('it', 'PRON'), ("'s", 'AUX'), ('just', 'ADV'), ('staying', 'VERB'), ('that', 'PRON'), ("'s", 'AUX'), ('what', 'PRON'), ('she', 'PRON'), ('said', 'VERB'), ('if', 'SCONJ'), ('she', 'PRON'), ('stepped', 'VERB'), ('along', 'ADP'), ('the', 'DET'), ('Deep', 'PROPN'), ('rutted', 'VERB'), ('grassy', 'PROPN'), ('Lane', 'PROPN'), ('at', 'ADP')]
# Entities for 103-1240-0019_16000Hz.wav: [('Mrs Rachel Lynde', 'PERSON'), ('Deep', 'PERSON'), ('Lane', 'WORK_OF_ART')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0010_16000Hz.wav
# Transcription: Peter had asked him of course for Matthew Cuthbert had never been known to volunteer information about anything in his whole life and yet here was Matthew Cuthbert at half past 3:00 on the afternoon of a busy day plastically driving over the hollow and up the hill
# Tokens for 103-1240-0010_16000Hz.wav: ['Peter', 'had', 'asked', 'him', 'of', 'course', 'for', 'Matthew', 'Cuthbert', 'had', 'never', 'been', 'known', 'to', 'volunteer', 'information', 'about', 'anything', 'in', 'his', 'whole', 'life', 'and', 'yet', 'here', 'was', 'Matthew', 'Cuthbert', 'at', 'half', 'past', '3:00', 'on', 'the', 'afternoon', 'of', 'a', 'busy', 'day', 'plastically', 'driving', 'over', 'the', 'hollow', 'and', 'up', 'the', 'hill']
# POS Tags for 103-1240-0010_16000Hz.wav: [('Peter', 'PROPN'), ('had', 'AUX'), ('asked', 'VERB'), ('him', 'PRON'), ('of', 'ADP'), ('course', 'NOUN'), ('for', 'ADP'), ('Matthew', 'PROPN'), ('Cuthbert', 'PROPN'), ('had', 'AUX'), ('never', 'ADV'), ('been', 'AUX'), ('known', 'VERB'), ('to', 'PART'), ('volunteer', 'VERB'), ('information', 'NOUN'), ('about', 'ADP'), ('anything', 'PRON'), ('in', 'ADP'), ('his', 'PRON'), ('whole', 'ADJ'), ('life', 'NOUN'), ('and', 'CCONJ'), ('yet', 'ADV'), ('here', 'ADV'), ('was', 'AUX'), ('Matthew', 'PROPN'), ('Cuthbert', 'PROPN'), ('at', 'ADP'), ('half', 'ADV'), ('past', 'ADP'), ('3:00', 'NUM'), ('on', 'ADP'), ('the', 'DET'), ('afternoon', 'NOUN'), ('of', 'ADP'), ('a', 'DET'), ('busy', 'ADJ'), ('day', 'NOUN'), ('plastically', 'ADV'), ('driving', 'VERB'), ('over', 'ADP'), ('the', 'DET'), ('hollow', 'ADJ'), ('and', 'CCONJ'), ('up', 'ADP'), ('the', 'DET'), ('hill', 'NOUN')]
# Entities for 103-1240-0010_16000Hz.wav: [('Peter', 'PERSON'), ('Matthew Cuthbert', 'PERSON'), ('Matthew Cuthbert', 'PERSON'), ('half past 3:00', 'TIME'), ('a busy day', 'DATE')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0054_16000Hz.wav
# Transcription: add Mrs Rachel dearly love to make a sensation so she took herself away someone to marilla's relief for the latter felt her doubts and fears Reviving under the influence of Mrs Rachel's pessimism well of all things that ever were or will be ejaculated Mrs Rachel when she was safely out in the Lane's what I
# Tokens for 103-1240-0054_16000Hz.wav: ['add', 'Mrs', 'Rachel', 'dearly', 'love', 'to', 'make', 'a', 'sensation', 'so', 'she', 'took', 'herself', 'away', 'someone', 'to', 'marilla', "'s", 'relief', 'for', 'the', 'latter', 'felt', 'her', 'doubts', 'and', 'fears', 'Reviving', 'under', 'the', 'influence', 'of', 'Mrs', 'Rachel', "'s", 'pessimism', 'well', 'of', 'all', 'things', 'that', 'ever', 'were', 'or', 'will', 'be', 'ejaculated', 'Mrs', 'Rachel', 'when', 'she', 'was', 'safely', 'out', 'in', 'the', 'Lane', "'s", 'what', 'I']
# POS Tags for 103-1240-0054_16000Hz.wav: [('add', 'VERB'), ('Mrs', 'PROPN'), ('Rachel', 'PROPN'), ('dearly', 'ADV'), ('love', 'VERB'), ('to', 'PART'), ('make', 'VERB'), ('a', 'DET'), ('sensation', 'NOUN'), ('so', 'SCONJ'), ('she', 'PRON'), ('took', 'VERB'), ('herself', 'PRON'), ('away', 'ADV'), ('someone', 'PRON'), ('to', 'ADP'), ('marilla', 'NOUN'), ("'s", 'PART'), ('relief', 'NOUN'), ('for', 'ADP'), ('the', 'DET'), ('latter', 'ADJ'), ('felt', 'VERB'), ('her', 'PRON'), ('doubts', 'NOUN'), ('and', 'CCONJ'), ('fears', 'VERB'), ('Reviving', 'PROPN'), ('under', 'ADP'), ('the', 'DET'), ('influence', 'NOUN'), ('of', 'ADP'), ('Mrs', 'PROPN'), ('Rachel', 'PROPN'), ("'s", 'PART'), ('pessimism', 'NOUN'), ('well', 'ADV'), ('of', 'ADP'), ('all', 'DET'), ('things', 'NOUN'), ('that', 'PRON'), ('ever', 'ADV'), ('were', 'AUX'), ('or', 'CCONJ'), ('will', 'AUX'), ('be', 'AUX'), ('ejaculated', 'VERB'), ('Mrs', 'PROPN'), ('Rachel', 'PROPN'), ('when', 'SCONJ'), ('she', 'PRON'), ('was', 'AUX'), ('safely', 'ADV'), ('out', 'ADV'), ('in', 'ADP'), ('the', 'DET'), ('Lane', 'PROPN'), ("'s", 'PART'), ('what', 'PRON'), ('I', 'PRON')]
# Entities for 103-1240-0054_16000Hz.wav: [('Mrs Rachel', 'PERSON'), ("Mrs Rachel's", 'PERSON'), ('Mrs Rachel', 'PERSON'), ('Lane', 'PERSON')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0007_16000Hz.wav
# Transcription: anybody who went out of it or into it had to pass over that Hill Road and so run the Unseen Gauntlet of Mrs Rachel's All-Seeing Eye she was sitting there one afternoon in early June the sun was coming in at the window warm and bright start up at
# Tokens for 103-1240-0007_16000Hz.wav: ['anybody', 'who', 'went', 'out', 'of', 'it', 'or', 'into', 'it', 'had', 'to', 'pass', 'over', 'that', 'Hill', 'Road', 'and', 'so', 'run', 'the', 'Unseen', 'Gauntlet', 'of', 'Mrs', 'Rachel', "'s", 'All', '-', 'Seeing', 'Eye', 'she', 'was', 'sitting', 'there', 'one', 'afternoon', 'in', 'early', 'June', 'the', 'sun', 'was', 'coming', 'in', 'at', 'the', 'window', 'warm', 'and', 'bright', 'start', 'up', 'at']
# POS Tags for 103-1240-0007_16000Hz.wav: [('anybody', 'PRON'), ('who', 'PRON'), ('went', 'VERB'), ('out', 'ADP'), ('of', 'ADP'), ('it', 'PRON'), ('or', 'CCONJ'), ('into', 'ADP'), ('it', 'PRON'), ('had', 'VERB'), ('to', 'PART'), ('pass', 'VERB'), ('over', 'ADP'), ('that', 'DET'), ('Hill', 'PROPN'), ('Road', 'PROPN'), ('and', 'CCONJ'), ('so', 'ADV'), ('run', 'VERB'), ('the', 'DET'), ('Unseen', 'PROPN'), ('Gauntlet', 'PROPN'), ('of', 'ADP'), ('Mrs', 'PROPN'), ('Rachel', 'PROPN'), ("'s", 'PART'), ('All', 'ADV'), ('-', 'PUNCT'), ('Seeing', 'VERB'), ('Eye', 'PROPN'), ('she', 'PRON'), ('was', 'AUX'), ('sitting', 'VERB'), ('there', 'ADV'), ('one', 'NUM'), ('afternoon', 'NOUN'), ('in', 'ADP'), ('early', 'ADJ'), ('June', 'PROPN'), ('the', 'DET'), ('sun', 'NOUN'), ('was', 'AUX'), ('coming', 'VERB'), ('in', 'ADP'), ('at', 'ADP'), ('the', 'DET'), ('window', 'NOUN'), ('warm', 'ADJ'), ('and', 'CCONJ'), ('bright', 'ADJ'), ('start', 'VERB'), ('up', 'ADP'), ('at', 'ADP')]
# Entities for 103-1240-0007_16000Hz.wav: [('Hill Road', 'FAC'), ('the Unseen Gauntlet', 'ORG'), ("Mrs Rachel's", 'PERSON'), ('one afternoon', 'TIME'), ('early June', 'DATE')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0026_16000Hz.wav
# Transcription: add here she sat now knitting and the table behind her was late for supper Mrs Rachel before she had Fairly closed the door
# Tokens for 103-1240-0026_16000Hz.wav: ['add', 'here', 'she', 'sat', 'now', 'knitting', 'and', 'the', 'table', 'behind', 'her', 'was', 'late', 'for', 'supper', 'Mrs', 'Rachel', 'before', 'she', 'had', 'Fairly', 'closed', 'the', 'door']
# POS Tags for 103-1240-0026_16000Hz.wav: [('add', 'VERB'), ('here', 'ADV'), ('she', 'PRON'), ('sat', 'VERB'), ('now', 'ADV'), ('knitting', 'VERB'), ('and', 'CCONJ'), ('the', 'DET'), ('table', 'NOUN'), ('behind', 'ADP'), ('her', 'PRON'), ('was', 'AUX'), ('late', 'ADJ'), ('for', 'ADP'), ('supper', 'NOUN'), ('Mrs', 'PROPN'), ('Rachel', 'PROPN'), ('before', 'SCONJ'), ('she', 'PRON'), ('had', 'AUX'), ('Fairly', 'ADV'), ('closed', 'VERB'), ('the', 'DET'), ('door', 'NOUN')]
# Entities for 103-1240-0026_16000Hz.wav: [('Mrs Rachel', 'PERSON'), ('Fairly', 'PERSON')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0043_16000Hz.wav
# Transcription: old enough to be of some use in doing chores right off and young enough to be trained up proper we mean to give him a good home and schooling we had a telegram for Mrs Alexander Spencer today the mailman brought it from the station saying they were coming on the 5:30 train tonight what
# Tokens for 103-1240-0043_16000Hz.wav: ['old', 'enough', 'to', 'be', 'of', 'some', 'use', 'in', 'doing', 'chores', 'right', 'off', 'and', 'young', 'enough', 'to', 'be', 'trained', 'up', 'proper', 'we', 'mean', 'to', 'give', 'him', 'a', 'good', 'home', 'and', 'schooling', 'we', 'had', 'a', 'telegram', 'for', 'Mrs', 'Alexander', 'Spencer', 'today', 'the', 'mailman', 'brought', 'it', 'from', 'the', 'station', 'saying', 'they', 'were', 'coming', 'on', 'the', '5:30', 'train', 'tonight', 'what']
# POS Tags for 103-1240-0043_16000Hz.wav: [('old', 'ADJ'), ('enough', 'ADV'), ('to', 'PART'), ('be', 'AUX'), ('of', 'ADP'), ('some', 'DET'), ('use', 'NOUN'), ('in', 'ADP'), ('doing', 'VERB'), ('chores', 'NOUN'), ('right', 'ADV'), ('off', 'ADV'), ('and', 'CCONJ'), ('young', 'ADJ'), ('enough', 'ADV'), ('to', 'PART'), ('be', 'AUX'), ('trained', 'VERB'), ('up', 'ADP'), ('proper', 'ADJ'), ('we', 'PRON'), ('mean', 'VERB'), ('to', 'PART'), ('give', 'VERB'), ('him', 'PRON'), ('a', 'DET'), ('good', 'ADJ'), ('home', 'NOUN'), ('and', 'CCONJ'), ('schooling', 'NOUN'), ('we', 'PRON'), ('had', 'VERB'), ('a', 'DET'), ('telegram', 'NOUN'), ('for', 'ADP'), ('Mrs', 'PROPN'), ('Alexander', 'PROPN'), ('Spencer', 'PROPN'), ('today', 'NOUN'), ('the', 'DET'), ('mailman', 'NOUN'), ('brought', 'VERB'), ('it', 'PRON'), ('from', 'ADP'), ('the', 'DET'), ('station', 'NOUN'), ('saying', 'VERB'), ('they', 'PRON'), ('were', 'AUX'), ('coming', 'VERB'), ('on', 'ADP'), ('the', 'DET'), ('5:30', 'NUM'), ('train', 'NOUN'), ('tonight', 'NOUN'), ('what', 'PRON')]
# Entities for 103-1240-0043_16000Hz.wav: [('Mrs Alexander Spencer', 'PERSON'), ('today', 'DATE'), ('tonight', 'TIME')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0051_16000Hz.wav
# Transcription: only don't say I didn't warn you if you burn the Green Gables down or put stricken in the well I heard of a case over in New Brunswick were an orphan Asylum child did that and the whole family died in fearful agonies only it was a girl in that instance well we're not getting a girl to Marilla
# Tokens for 103-1240-0051_16000Hz.wav: ['only', 'do', "n't", 'say', 'I', 'did', "n't", 'warn', 'you', 'if', 'you', 'burn', 'the', 'Green', 'Gables', 'down', 'or', 'put', 'stricken', 'in', 'the', 'well', 'I', 'heard', 'of', 'a', 'case', 'over', 'in', 'New', 'Brunswick', 'were', 'an', 'orphan', 'Asylum', 'child', 'did', 'that', 'and', 'the', 'whole', 'family', 'died', 'in', 'fearful', 'agonies', 'only', 'it', 'was', 'a', 'girl', 'in', 'that', 'instance', 'well', 'we', "'re", 'not', 'getting', 'a', 'girl', 'to', 'Marilla']
# POS Tags for 103-1240-0051_16000Hz.wav: [('only', 'ADV'), ('do', 'AUX'), ("n't", 'PART'), ('say', 'VERB'), ('I', 'PRON'), ('did', 'AUX'), ("n't", 'PART'), ('warn', 'VERB'), ('you', 'PRON'), ('if', 'SCONJ'), ('you', 'PRON'), ('burn', 'VERB'), ('the', 'DET'), ('Green', 'PROPN'), ('Gables', 'PROPN'), ('down', 'ADP'), ('or', 'CCONJ'), ('put', 'VERB'), ('stricken', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('well', 'NOUN'), ('I', 'PRON'), ('heard', 'VERB'), ('of', 'ADP'), ('a', 'DET'), ('case', 'NOUN'), ('over', 'ADP'), ('in', 'ADP'), ('New', 'PROPN'), ('Brunswick', 'PROPN'), ('were', 'AUX'), ('an', 'DET'), ('orphan', 'NOUN'), ('Asylum', 'PROPN'), ('child', 'NOUN'), ('did', 'VERB'), ('that', 'PRON'), ('and', 'CCONJ'), ('the', 'DET'), ('whole', 'ADJ'), ('family', 'NOUN'), ('died', 'VERB'), ('in', 'ADP'), ('fearful', 'ADJ'), ('agonies', 'NOUN'), ('only', 'ADV'), ('it', 'PRON'), ('was', 'AUX'), ('a', 'DET'), ('girl', 'NOUN'), ('in', 'ADP'), ('that', 'DET'), ('instance', 'NOUN'), ('well', 'INTJ'), ('we', 'PRON'), ("'re", 'AUX'), ('not', 'PART'), ('getting', 'VERB'), ('a', 'DET'), ('girl', 'NOUN'), ('to', 'ADP'), ('Marilla', 'PROPN')]
# Entities for 103-1240-0051_16000Hz.wav: [('New Brunswick', 'GPE'), ('Marilla', 'NORP')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0037_16000Hz.wav
# Transcription: what's on Earth but such a notion into your head she demanded disapprovingly this had been done without her advice being asked and must perform be disproved well we've been thinking about it for some time all winter in fact returned Marilla
# Tokens for 103-1240-0037_16000Hz.wav: ['what', "'s", 'on', 'Earth', 'but', 'such', 'a', 'notion', 'into', 'your', 'head', 'she', 'demanded', 'disapprovingly', 'this', 'had', 'been', 'done', 'without', 'her', 'advice', 'being', 'asked', 'and', 'must', 'perform', 'be', 'disproved', 'well', 'we', "'ve", 'been', 'thinking', 'about', 'it', 'for', 'some', 'time', 'all', 'winter', 'in', 'fact', 'returned', 'Marilla']
# POS Tags for 103-1240-0037_16000Hz.wav: [('what', 'PRON'), ("'s", 'AUX'), ('on', 'ADP'), ('Earth', 'PROPN'), ('but', 'CCONJ'), ('such', 'DET'), ('a', 'DET'), ('notion', 'NOUN'), ('into', 'ADP'), ('your', 'PRON'), ('head', 'NOUN'), ('she', 'PRON'), ('demanded', 'VERB'), ('disapprovingly', 'ADV'), ('this', 'PRON'), ('had', 'AUX'), ('been', 'AUX'), ('done', 'VERB'), ('without', 'ADP'), ('her', 'PRON'), ('advice', 'NOUN'), ('being', 'AUX'), ('asked', 'VERB'), ('and', 'CCONJ'), ('must', 'AUX'), ('perform', 'VERB'), ('be', 'AUX'), ('disproved', 'VERB'), ('well', 'INTJ'), ('we', 'PRON'), ("'ve", 'AUX'), ('been', 'AUX'), ('thinking', 'VERB'), ('about', 'ADP'), ('it', 'PRON'), ('for', 'ADP'), ('some', 'DET'), ('time', 'NOUN'), ('all', 'DET'), ('winter', 'NOUN'), ('in', 'ADP'), ('fact', 'NOUN'), ('returned', 'VERB'), ('Marilla', 'PROPN')]
# Entities for 103-1240-0037_16000Hz.wav: [('Earth', 'LOC'), ('Marilla', 'ORG')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0013_16000Hz.wav
# Transcription: he was the shyest man alive and hated to have to go among strangers or to any place where he might have to talk Matthew dressed up with a white collar and driving in a buggy was something that didn't happen often Mrs Rachel ponderous she might could make nothing of it what are
# Tokens for 103-1240-0013_16000Hz.wav: ['he', 'was', 'the', 'shyest', 'man', 'alive', 'and', 'hated', 'to', 'have', 'to', 'go', 'among', 'strangers', 'or', 'to', 'any', 'place', 'where', 'he', 'might', 'have', 'to', 'talk', 'Matthew', 'dressed', 'up', 'with', 'a', 'white', 'collar', 'and', 'driving', 'in', 'a', 'buggy', 'was', 'something', 'that', 'did', "n't", 'happen', 'often', 'Mrs', 'Rachel', 'ponderous', 'she', 'might', 'could', 'make', 'nothing', 'of', 'it', 'what', 'are']
# POS Tags for 103-1240-0013_16000Hz.wav: [('he', 'PRON'), ('was', 'AUX'), ('the', 'DET'), ('shyest', 'ADJ'), ('man', 'NOUN'), ('alive', 'ADJ'), ('and', 'CCONJ'), ('hated', 'VERB'), ('to', 'PART'), ('have', 'VERB'), ('to', 'PART'), ('go', 'VERB'), ('among', 'ADP'), ('strangers', 'NOUN'), ('or', 'CCONJ'), ('to', 'ADP'), ('any', 'DET'), ('place', 'NOUN'), ('where', 'SCONJ'), ('he', 'PRON'), ('might', 'AUX'), ('have', 'VERB'), ('to', 'PART'), ('talk', 'VERB'), ('Matthew', 'PROPN'), ('dressed', 'VERB'), ('up', 'ADP'), ('with', 'ADP'), ('a', 'DET'), ('white', 'ADJ'), ('collar', 'NOUN'), ('and', 'CCONJ'), ('driving', 'VERB'), ('in', 'ADP'), ('a', 'DET'), ('buggy', 'ADJ'), ('was', 'AUX'), ('something', 'PRON'), ('that', 'PRON'), ('did', 'AUX'), ("n't", 'PART'), ('happen', 'VERB'), ('often', 'ADV'), ('Mrs', 'PROPN'), ('Rachel', 'PROPN'), ('ponderous', 'ADJ'), ('she', 'PRON'), ('might', 'AUX'), ('could', 'AUX'), ('make', 'VERB'), ('nothing', 'PRON'), ('of', 'ADP'), ('it', 'PRON'), ('what', 'PRON'), ('are', 'AUX')]
# Entities for 103-1240-0013_16000Hz.wav: [('Matthew', 'PERSON'), ('Mrs Rachel', 'PERSON')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0017_16000Hz.wav
# Transcription: the big rambling Orchard and Ballard house where the cuthberts lived was a scanned quarter of a mile up the road from Lynn's Hollow to be sure the long Lane made it a good deal further Matthew cuthbert's father as shy and Silent as his son after himself
# Tokens for 103-1240-0017_16000Hz.wav: ['the', 'big', 'rambling', 'Orchard', 'and', 'Ballard', 'house', 'where', 'the', 'cuthberts', 'lived', 'was', 'a', 'scanned', 'quarter', 'of', 'a', 'mile', 'up', 'the', 'road', 'from', 'Lynn', "'s", 'Hollow', 'to', 'be', 'sure', 'the', 'long', 'Lane', 'made', 'it', 'a', 'good', 'deal', 'further', 'Matthew', 'cuthbert', "'s", 'father', 'as', 'shy', 'and', 'Silent', 'as', 'his', 'son', 'after', 'himself']
# POS Tags for 103-1240-0017_16000Hz.wav: [('the', 'DET'), ('big', 'ADJ'), ('rambling', 'VERB'), ('Orchard', 'PROPN'), ('and', 'CCONJ'), ('Ballard', 'PROPN'), ('house', 'NOUN'), ('where', 'SCONJ'), ('the', 'DET'), ('cuthberts', 'NOUN'), ('lived', 'VERB'), ('was', 'AUX'), ('a', 'DET'), ('scanned', 'ADJ'), ('quarter', 'NOUN'), ('of', 'ADP'), ('a', 'DET'), ('mile', 'NOUN'), ('up', 'ADP'), ('the', 'DET'), ('road', 'NOUN'), ('from', 'ADP'), ('Lynn', 'PROPN'), ("'s", 'PART'), ('Hollow', 'PROPN'), ('to', 'PART'), ('be', 'AUX'), ('sure', 'ADJ'), ('the', 'DET'), ('long', 'ADJ'), ('Lane', 'PROPN'), ('made', 'VERB'), ('it', 'PRON'), ('a', 'DET'), ('good', 'ADJ'), ('deal', 'NOUN'), ('further', 'ADJ'), ('Matthew', 'PROPN'), ('cuthbert', 'PROPN'), ("'s", 'PART'), ('father', 'NOUN'), ('as', 'ADV'), ('shy', 'ADJ'), ('and', 'CCONJ'), ('Silent', 'ADJ'), ('as', 'ADP'), ('his', 'PRON'), ('son', 'NOUN'), ('after', 'ADP'), ('himself', 'PRON')]
# Entities for 103-1240-0017_16000Hz.wav: [('Orchard', 'PERSON'), ('Ballard', 'PERSON'), ('quarter of a mile', 'QUANTITY'), ('Lynn', 'PERSON'), ('Lane', 'PERSON'), ("Matthew cuthbert's", 'PERSON'), ('Silent', 'PERSON')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0034_16000Hz.wav
# Transcription: Marilla was making fun of her but Mrs Rachel was almost forced to supposed are you an Earnest Marilla she demanded when voice returned to her yes of course what I don't
# Tokens for 103-1240-0034_16000Hz.wav: ['Marilla', 'was', 'making', 'fun', 'of', 'her', 'but', 'Mrs', 'Rachel', 'was', 'almost', 'forced', 'to', 'supposed', 'are', 'you', 'an', 'Earnest', 'Marilla', 'she', 'demanded', 'when', 'voice', 'returned', 'to', 'her', 'yes', 'of', 'course', 'what', 'I', 'do', "n't"]
# POS Tags for 103-1240-0034_16000Hz.wav: [('Marilla', 'PROPN'), ('was', 'AUX'), ('making', 'VERB'), ('fun', 'NOUN'), ('of', 'ADP'), ('her', 'PRON'), ('but', 'CCONJ'), ('Mrs', 'PROPN'), ('Rachel', 'PROPN'), ('was', 'AUX'), ('almost', 'ADV'), ('forced', 'VERB'), ('to', 'PART'), ('supposed', 'VERB'), ('are', 'AUX'), ('you', 'PRON'), ('an', 'DET'), ('Earnest', 'ADJ'), ('Marilla', 'PROPN'), ('she', 'PRON'), ('demanded', 'VERB'), ('when', 'SCONJ'), ('voice', 'NOUN'), ('returned', 'VERB'), ('to', 'ADP'), ('her', 'PRON'), ('yes', 'INTJ'), ('of', 'ADP'), ('course', 'NOUN'), ('what', 'PRON'), ('I', 'PRON'), ('do', 'VERB'), ("n't", 'PART')]
# Entities for 103-1240-0034_16000Hz.wav: [('Mrs Rachel', 'PERSON')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0032_16000Hz.wav
# Transcription: marilla's lips twitched understandingly she had expected Mrs Rachel up she had known that the sight of Matthew jaunting off so unaccountably would be too much for her neighbors curiosity oh no I'm quite well although I had a bad headache yesterday she said what
# Tokens for 103-1240-0032_16000Hz.wav: ['marilla', "'s", 'lips', 'twitched', 'understandingly', 'she', 'had', 'expected', 'Mrs', 'Rachel', 'up', 'she', 'had', 'known', 'that', 'the', 'sight', 'of', 'Matthew', 'jaunting', 'off', 'so', 'unaccountably', 'would', 'be', 'too', 'much', 'for', 'her', 'neighbors', 'curiosity', 'oh', 'no', 'I', "'m", 'quite', 'well', 'although', 'I', 'had', 'a', 'bad', 'headache', 'yesterday', 'she', 'said', 'what']
# POS Tags for 103-1240-0032_16000Hz.wav: [('marilla', 'PROPN'), ("'s", 'PART'), ('lips', 'NOUN'), ('twitched', 'VERB'), ('understandingly', 'ADV'), ('she', 'PRON'), ('had', 'AUX'), ('expected', 'VERB'), ('Mrs', 'PROPN'), ('Rachel', 'PROPN'), ('up', 'ADP'), ('she', 'PRON'), ('had', 'AUX'), ('known', 'VERB'), ('that', 'SCONJ'), ('the', 'DET'), ('sight', 'NOUN'), ('of', 'ADP'), ('Matthew', 'PROPN'), ('jaunting', 'VERB'), ('off', 'ADP'), ('so', 'ADV'), ('unaccountably', 'ADV'), ('would', 'AUX'), ('be', 'AUX'), ('too', 'ADV'), ('much', 'ADJ'), ('for', 'ADP'), ('her', 'PRON'), ('neighbors', 'NOUN'), ('curiosity', 'NOUN'), ('oh', 'INTJ'), ('no', 'INTJ'), ('I', 'PRON'), ("'m", 'AUX'), ('quite', 'ADV'), ('well', 'ADV'), ('although', 'SCONJ'), ('I', 'PRON'), ('had', 'VERB'), ('a', 'DET'), ('bad', 'ADJ'), ('headache', 'NOUN'), ('yesterday', 'NOUN'), ('she', 'PRON'), ('said', 'VERB'), ('what', 'PRON')]
# Entities for 103-1240-0032_16000Hz.wav: [('Mrs Rachel', 'PERSON'), ('Matthew', 'PERSON'), ('yesterday', 'DATE')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0041_16000Hz.wav
# Transcription: they may be all right I'm not saying they're not but no London Street Arabs for me I said give me a native board at least that'll be a risk no matter who we get but I'll feel easy in my mind and sleep Sounder at night if we get a boring Canadians what what
# Tokens for 103-1240-0041_16000Hz.wav: ['they', 'may', 'be', 'all', 'right', 'I', "'m", 'not', 'saying', 'they', "'re", 'not', 'but', 'no', 'London', 'Street', 'Arabs', 'for', 'me', 'I', 'said', 'give', 'me', 'a', 'native', 'board', 'at', 'least', 'that', "'ll", 'be', 'a', 'risk', 'no', 'matter', 'who', 'we', 'get', 'but', 'I', "'ll", 'feel', 'easy', 'in', 'my', 'mind', 'and', 'sleep', 'Sounder', 'at', 'night', 'if', 'we', 'get', 'a', 'boring', 'Canadians', 'what', 'what']
# POS Tags for 103-1240-0041_16000Hz.wav: [('they', 'PRON'), ('may', 'AUX'), ('be', 'AUX'), ('all', 'ADV'), ('right', 'ADJ'), ('I', 'PRON'), ("'m", 'AUX'), ('not', 'PART'), ('saying', 'VERB'), ('they', 'PRON'), ("'re", 'AUX'), ('not', 'PART'), ('but', 'CCONJ'), ('no', 'DET'), ('London', 'PROPN'), ('Street', 'PROPN'), ('Arabs', 'PROPN'), ('for', 'ADP'), ('me', 'PRON'), ('I', 'PRON'), ('said', 'VERB'), ('give', 'VERB'), ('me', 'PRON'), ('a', 'DET'), ('native', 'ADJ'), ('board', 'NOUN'), ('at', 'ADP'), ('least', 'ADJ'), ('that', 'PRON'), ("'ll", 'AUX'), ('be', 'AUX'), ('a', 'DET'), ('risk', 'NOUN'), ('no', 'ADV'), ('matter', 'ADV'), ('who', 'PRON'), ('we', 'PRON'), ('get', 'VERB'), ('but', 'CCONJ'), ('I', 'PRON'), ("'ll", 'AUX'), ('feel', 'VERB'), ('easy', 'ADJ'), ('in', 'ADP'), ('my', 'PRON'), ('mind', 'NOUN'), ('and', 'CCONJ'), ('sleep', 'VERB'), ('Sounder', 'PROPN'), ('at', 'ADP'), ('night', 'NOUN'), ('if', 'SCONJ'), ('we', 'PRON'), ('get', 'VERB'), ('a', 'DET'), ('boring', 'ADJ'), ('Canadians', 'PROPN'), ('what', 'PRON'), ('what', 'PRON')]
# Entities for 103-1240-0041_16000Hz.wav: [('Sounder', 'PRODUCT'), ('Canadians', 'NORP')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0009_16000Hz.wav
# Transcription: Mrs Rachel knew that he ought because she had heard him tell Peter Morris in the evening before in William J Blair store over at Carmody that he meant to show his turnip seed the next afternoon what are
# Tokens for 103-1240-0009_16000Hz.wav: ['Mrs', 'Rachel', 'knew', 'that', 'he', 'ought', 'because', 'she', 'had', 'heard', 'him', 'tell', 'Peter', 'Morris', 'in', 'the', 'evening', 'before', 'in', 'William', 'J', 'Blair', 'store', 'over', 'at', 'Carmody', 'that', 'he', 'meant', 'to', 'show', 'his', 'turnip', 'seed', 'the', 'next', 'afternoon', 'what', 'are']
# POS Tags for 103-1240-0009_16000Hz.wav: [('Mrs', 'PROPN'), ('Rachel', 'PROPN'), ('knew', 'VERB'), ('that', 'SCONJ'), ('he', 'PRON'), ('ought', 'AUX'), ('because', 'SCONJ'), ('she', 'PRON'), ('had', 'AUX'), ('heard', 'VERB'), ('him', 'PRON'), ('tell', 'VERB'), ('Peter', 'PROPN'), ('Morris', 'PROPN'), ('in', 'ADP'), ('the', 'DET'), ('evening', 'NOUN'), ('before', 'ADV'), ('in', 'ADP'), ('William', 'PROPN'), ('J', 'PROPN'), ('Blair', 'PROPN'), ('store', 'NOUN'), ('over', 'ADP'), ('at', 'ADP'), ('Carmody', 'PROPN'), ('that', 'SCONJ'), ('he', 'PRON'), ('meant', 'VERB'), ('to', 'PART'), ('show', 'VERB'), ('his', 'PRON'), ('turnip', 'NOUN'), ('seed', 'NOUN'), ('the', 'DET'), ('next', 'ADJ'), ('afternoon', 'NOUN'), ('what', 'PRON'), ('are', 'AUX')]
# Entities for 103-1240-0009_16000Hz.wav: [('Mrs Rachel', 'PERSON'), ('Peter Morris', 'PERSON'), ('evening', 'TIME'), ('William J Blair', 'PERSON'), ('Carmody', 'ORG')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0003_16000Hz.wav
# Transcription: and that if she noticed anything odd or out of place she would never rest until she had ferreted out the whys and wherefores their of there are plenty of people in Avonlea and out of it who can attend closely to their neighbor's business by dint of neglecting their own
# Tokens for 103-1240-0003_16000Hz.wav: ['and', 'that', 'if', 'she', 'noticed', 'anything', 'odd', 'or', 'out', 'of', 'place', 'she', 'would', 'never', 'rest', 'until', 'she', 'had', 'ferreted', 'out', 'the', 'why', 's', 'and', 'wherefores', 'their', 'of', 'there', 'are', 'plenty', 'of', 'people', 'in', 'Avonlea', 'and', 'out', 'of', 'it', 'who', 'can', 'attend', 'closely', 'to', 'their', 'neighbor', "'s", 'business', 'by', 'dint', 'of', 'neglecting', 'their', 'own']
# POS Tags for 103-1240-0003_16000Hz.wav: [('and', 'CCONJ'), ('that', 'SCONJ'), ('if', 'SCONJ'), ('she', 'PRON'), ('noticed', 'VERB'), ('anything', 'PRON'), ('odd', 'ADJ'), ('or', 'CCONJ'), ('out', 'ADP'), ('of', 'ADP'), ('place', 'NOUN'), ('she', 'PRON'), ('would', 'AUX'), ('never', 'ADV'), ('rest', 'VERB'), ('until', 'SCONJ'), ('she', 'PRON'), ('had', 'AUX'), ('ferreted', 'VERB'), ('out', 'ADP'), ('the', 'DET'), ('why', 'SCONJ'), ('s', 'NOUN'), ('and', 'CCONJ'), ('wherefores', 'VERB'), ('their', 'PRON'), ('of', 'ADP'), ('there', 'PRON'), ('are', 'VERB'), ('plenty', 'NOUN'), ('of', 'ADP'), ('people', 'NOUN'), ('in', 'ADP'), ('Avonlea', 'PROPN'), ('and', 'CCONJ'), ('out', 'ADP'), ('of', 'ADP'), ('it', 'PRON'), ('who', 'PRON'), ('can', 'AUX'), ('attend', 'VERB'), ('closely', 'ADV'), ('to', 'ADP'), ('their', 'PRON'), ('neighbor', 'NOUN'), ("'s", 'PART'), ('business', 'NOUN'), ('by', 'ADP'), ('dint', 'NOUN'), ('of', 'ADP'), ('neglecting', 'VERB'), ('their', 'PRON'), ('own', 'ADJ')]
# Entities for 103-1240-0003_16000Hz.wav: [('Avonlea', 'GPE')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0012_16000Hz.wav
# ...
# Entities for 103-1240-0021_16000Hz.wav: [('Irishman', 'NORP'), ('this Mrs Rachel', 'FAC'), ('Green Gables', 'ORG')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0001_16000Hz.wav
# Transcription: that had its source a way back in the woods of the old Cuthbert place it was reputed to be an intricate headlong book in his earlier course through those woods with dark secrets of pool and Cascade but by the time it reached Lin's Hollow it was a quiet well-conducted little streaming
# Tokens for 103-1240-0001_16000Hz.wav: ['that', 'had', 'its', 'source', 'a', 'way', 'back', 'in', 'the', 'woods', 'of', 'the', 'old', 'Cuthbert', 'place', 'it', 'was', 'reputed', 'to', 'be', 'an', 'intricate', 'headlong', 'book', 'in', 'his', 'earlier', 'course', 'through', 'those', 'woods', 'with', 'dark', 'secrets', 'of', 'pool', 'and', 'Cascade', 'but', 'by', 'the', 'time', 'it', 'reached', 'Lin', "'s", 'Hollow', 'it', 'was', 'a', 'quiet', 'well', '-', 'conducted', 'little', 'streaming']
# POS Tags for 103-1240-0001_16000Hz.wav: [('that', 'PRON'), ('had', 'VERB'), ('its', 'PRON'), ('source', 'NOUN'), ('a', 'DET'), ('way', 'NOUN'), ('back', 'ADV'), ('in', 'ADP'), ('the', 'DET'), ('woods', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('old', 'ADJ'), ('Cuthbert', 'PROPN'), ('place', 'NOUN'), ('it', 'PRON'), ('was', 'AUX'), ('reputed', 'VERB'), ('to', 'PART'), ('be', 'AUX'), ('an', 'DET'), ('intricate', 'ADJ'), ('headlong', 'NOUN'), ('book', 'NOUN'), ('in', 'ADP'), ('his', 'PRON'), ('earlier', 'ADJ'), ('course', 'NOUN'), ('through', 'ADP'), ('those', 'DET'), ('woods', 'NOUN'), ('with', 'ADP'), ('dark', 'ADJ'), ('secrets', 'NOUN'), ('of', 'ADP'), ('pool', 'NOUN'), ('and', 'CCONJ'), ('Cascade', 'PROPN'), ('but', 'CCONJ'), ('by', 'ADP'), ('the', 'DET'), ('time', 'NOUN'), ('it', 'PRON'), ('reached', 'VERB'), ('Lin', 'PROPN'), ("'s", 'PART'), ('Hollow', 'PROPN'), ('it', 'PRON'), ('was', 'AUX'), ('a', 'DET'), ('quiet', 'ADJ'), ('well', 'ADV'), ('-', 'PUNCT'), ('conducted', 'VERB'), ('little', 'ADJ'), ('streaming', 'NOUN')]
# Entities for 103-1240-0001_16000Hz.wav: [('Cuthbert', 'PERSON'), ('Cascade', 'PERSON'), ('Lin', 'PERSON')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0023_16000Hz.wav
# Transcription: one could have eaten a meal off the ground without over brimming the proverbial peck of dirt Mrs Rachel wrapped smartly at the kitchen door and stepped in when bitten to do so the kitchen at Green Gables was a cheerful department at
# Tokens for 103-1240-0023_16000Hz.wav: ['one', 'could', 'have', 'eaten', 'a', 'meal', 'off', 'the', 'ground', 'without', 'over', 'brimming', 'the', 'proverbial', 'peck', 'of', 'dirt', 'Mrs', 'Rachel', 'wrapped', 'smartly', 'at', 'the', 'kitchen', 'door', 'and', 'stepped', 'in', 'when', 'bitten', 'to', 'do', 'so', 'the', 'kitchen', 'at', 'Green', 'Gables', 'was', 'a', 'cheerful', 'department', 'at']
# POS Tags for 103-1240-0023_16000Hz.wav: [('one', 'PRON'), ('could', 'AUX'), ('have', 'AUX'), ('eaten', 'VERB'), ('a', 'DET'), ('meal', 'NOUN'), ('off', 'ADP'), ('the', 'DET'), ('ground', 'NOUN'), ('without', 'ADP'), ('over', 'ADP'), ('brimming', 'VERB'), ('the', 'DET'), ('proverbial', 'ADJ'), ('peck', 'NOUN'), ('of', 'ADP'), ('dirt', 'NOUN'), ('Mrs', 'PROPN'), ('Rachel', 'PROPN'), ('wrapped', 'VERB'), ('smartly', 'ADV'), ('at', 'ADP'), ('the', 'DET'), ('kitchen', 'NOUN'), ('door', 'NOUN'), ('and', 'CCONJ'), ('stepped', 'VERB'), ('in', 'ADV'), ('when', 'SCONJ'), ('bitten', 'VERB'), ('to', 'PART'), ('do', 'VERB'), ('so', 'ADV'), ('the', 'DET'), ('kitchen', 'NOUN'), ('at', 'ADP'), ('Green', 'PROPN'), ('Gables', 'PROPN'), ('was', 'AUX'), ('a', 'DET'), ('cheerful', 'ADJ'), ('department', 'NOUN'), ('at', 'ADP')]
# Entities for 103-1240-0023_16000Hz.wav: [('Mrs Rachel', 'PERSON'), ('Green Gables', 'ORG')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0056_16000Hz.wav
# Transcription: it seems uncanny to think of a child that Green Gables somehow there's never been one there for Matthew and Marilla were grown up when the new house was built if they ever were children which is hard to believe when one looks at them I wouldn't be in that orphans shoes for anything at
# Tokens for 103-1240-0056_16000Hz.wav: ['it', 'seems', 'uncanny', 'to', 'think', 'of', 'a', 'child', 'that', 'Green', 'Gables', 'somehow', 'there', "'s", 'never', 'been', 'one', 'there', 'for', 'Matthew', 'and', 'Marilla', 'were', 'grown', 'up', 'when', 'the', 'new', 'house', 'was', 'built', 'if', 'they', 'ever', 'were', 'children', 'which', 'is', 'hard', 'to', 'believe', 'when', 'one', 'looks', 'at', 'them', 'I', 'would', "n't", 'be', 'in', 'that', 'orphans', 'shoes', 'for', 'anything', 'at']
# POS Tags for 103-1240-0056_16000Hz.wav: [('it', 'PRON'), ('seems', 'VERB'), ('uncanny', 'ADJ'), ('to', 'PART'), ('think', 'VERB'), ('of', 'ADP'), ('a', 'DET'), ('child', 'NOUN'), ('that', 'PRON'), ('Green', 'PROPN'), ('Gables', 'PROPN'), ('somehow', 'ADV'), ('there', 'PRON'), ("'s", 'VERB'), ('never', 'ADV'), ('been', 'AUX'), ('one', 'NUM'), ('there', 'ADV'), ('for', 'ADP'), ('Matthew', 'PROPN'), ('and', 'CCONJ'), ('Marilla', 'PROPN'), ('were', 'AUX'), ('grown', 'VERB'), ('up', 'ADP'), ('when', 'SCONJ'), ('the', 'DET'), ('new', 'ADJ'), ('house', 'NOUN'), ('was', 'AUX'), ('built', 'VERB'), ('if', 'SCONJ'), ('they', 'PRON'), ('ever', 'ADV'), ('were', 'AUX'), ('children', 'NOUN'), ('which', 'PRON'), ('is', 'AUX'), ('hard', 'ADJ'), ('to', 'PART'), ('believe', 'VERB'), ('when', 'SCONJ'), ('one', 'PRON'), ('looks', 'VERB'), ('at', 'ADP'), ('them', 'PRON'), ('I', 'PRON'), ('would', 'AUX'), ("n't", 'PART'), ('be', 'AUX'), ('in', 'ADP'), ('that', 'DET'), ('orphans', 'NOUN'), ('shoes', 'NOUN'), ('for', 'ADP'), ('anything', 'PRON'), ('at', 'ADP')]
# Entities for 103-1240-0056_16000Hz.wav: [('Green Gables', 'ORG'), ('Matthew', 'PERSON'), ('Marilla', 'PERSON'), ('one', 'CARDINAL')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0049_16000Hz.wav
# Transcription: it's so seldom Matthew sets his mind on anything that when he does I always feel it's my duty to give in and ask for the risk there's risks in pretty near everything at body does in this world there is risks and people having children of their own if it comes to that they don't always turn out well go to
# Tokens for 103-1240-0049_16000Hz.wav: ['it', "'s", 'so', 'seldom', 'Matthew', 'sets', 'his', 'mind', 'on', 'anything', 'that', 'when', 'he', 'does', 'I', 'always', 'feel', 'it', "'s", 'my', 'duty', 'to', 'give', 'in', 'and', 'ask', 'for', 'the', 'risk', 'there', "'s", 'risks', 'in', 'pretty', 'near', 'everything', 'at', 'body', 'does', 'in', 'this', 'world', 'there', 'is', 'risks', 'and', 'people', 'having', 'children', 'of', 'their', 'own', 'if', 'it', 'comes', 'to', 'that', 'they', 'do', "n't", 'always', 'turn', 'out', 'well', 'go', 'to']
# POS Tags for 103-1240-0049_16000Hz.wav: [('it', 'PRON'), ("'s", 'AUX'), ('so', 'ADV'), ('seldom', 'ADV'), ('Matthew', 'PROPN'), ('sets', 'VERB'), ('his', 'PRON'), ('mind', 'NOUN'), ('on', 'ADP'), ('anything', 'PRON'), ('that', 'SCONJ'), ('when', 'SCONJ'), ('he', 'PRON'), ('does', 'AUX'), ('I', 'PRON'), ('always', 'ADV'), ('feel', 'VERB'), ('it', 'PRON'), ("'s", 'AUX'), ('my', 'PRON'), ('duty', 'NOUN'), ('to', 'PART'), ('give', 'VERB'), ('in', 'ADP'), ('and', 'CCONJ'), ('ask', 'VERB'), ('for', 'ADP'), ('the', 'DET'), ('risk', 'NOUN'), ('there', 'PRON'), ("'s", 'VERB'), ('risks', 'NOUN'), ('in', 'ADP'), ('pretty', 'ADV'), ('near', 'ADP'), ('everything', 'PRON'), ('at', 'ADP'), ('body', 'NOUN'), ('does', 'VERB'), ('in', 'ADP'), ('this', 'DET'), ('world', 'NOUN'), ('there', 'PRON'), ('is', 'VERB'), ('risks', 'NOUN'), ('and', 'CCONJ'), ('people', 'NOUN'), ('having', 'VERB'), ('children', 'NOUN'), ('of', 'ADP'), ('their', 'PRON'), ('own', 'ADJ'), ('if', 'SCONJ'), ('it', 'PRON'), ('comes', 'VERB'), ('to', 'ADP'), ('that', 'SCONJ'), ('they', 'PRON'), ('do', 'AUX'), ("n't", 'PART'), ('always', 'ADV'), ('turn', 'VERB'), ('out', 'ADP'), ('well', 'INTJ'), ('go', 'VERB'), ('to', 'ADP')]
# Entities for 103-1240-0049_16000Hz.wav: [('Matthew', 'PERSON')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0040_16000Hz.wav
# Transcription: there's never anybody to be had but those stupid half-grown little French boys and as soon as you do get one broke into your ways and taught something he's up and off to the Lobster canneries or the states at First Matthew suggested getting a homeboy but I said no flat to that what
# Tokens for 103-1240-0040_16000Hz.wav: ['there', "'s", 'never', 'anybody', 'to', 'be', 'had', 'but', 'those', 'stupid', 'half', '-', 'grown', 'little', 'French', 'boys', 'and', 'as', 'soon', 'as', 'you', 'do', 'get', 'one', 'broke', 'into', 'your', 'ways', 'and', 'taught', 'something', 'he', "'s", 'up', 'and', 'off', 'to', 'the', 'Lobster', 'canneries', 'or', 'the', 'states', 'at', 'First', 'Matthew', 'suggested', 'getting', 'a', 'homeboy', 'but', 'I', 'said', 'no', 'flat', 'to', 'that', 'what']
# POS Tags for 103-1240-0040_16000Hz.wav: [('there', 'PRON'), ("'s", 'VERB'), ('never', 'ADV'), ('anybody', 'PRON'), ('to', 'PART'), ('be', 'AUX'), ('had', 'VERB'), ('but', 'CCONJ'), ('those', 'DET'), ('stupid', 'ADJ'), ('half', 'ADV'), ('-', 'PUNCT'), ('grown', 'VERB'), ('little', 'ADJ'), ('French', 'ADJ'), ('boys', 'NOUN'), ('and', 'CCONJ'), ('as', 'ADV'), ('soon', 'ADV'), ('as', 'SCONJ'), ('you', 'PRON'), ('do', 'AUX'), ('get', 'VERB'), ('one', 'NUM'), ('broke', 'VERB'), ('into', 'ADP'), ('your', 'PRON'), ('ways', 'NOUN'), ('and', 'CCONJ'), ('taught', 'VERB'), ('something', 'PRON'), ('he', 'PRON'), ("'s", 'AUX'), ('up', 'ADV'), ('and', 'CCONJ'), ('off', 'ADP'), ('to', 'ADP'), ('the', 'DET'), ('Lobster', 'PROPN'), ('canneries', 'NOUN'), ('or', 'CCONJ'), ('the', 'DET'), ('states', 'NOUN'), ('at', 'ADP'), ('First', 'PROPN'), ('Matthew', 'PROPN'), ('suggested', 'VERB'), ('getting', 'VERB'), ('a', 'DET'), ('homeboy', 'NOUN'), ('but', 'CCONJ'), ('I', 'PRON'), ('said', 'VERB'), ('no', 'DET'), ('flat', 'ADJ'), ('to', 'ADP'), ('that', 'PRON'), ('what', 'PRON')]
# Entities for 103-1240-0040_16000Hz.wav: [('half', 'CARDINAL'), ('French', 'NORP'), ('Lobster', 'PERSON'), ('First Matthew', 'ORG')]
# 🔊 Noisy audio saved to /kaggle/working/noisy_audio_files/noisy_103-1240-0020_16000Hz.wav
# Transcription: bored with wild rose bushes it's no wonder Matthew and Marilla are both a little odd living a way back here by themselves trees aren't much company though dear knows if they were there'd be enough of them I'd rather look at people to be sure what
# Tokens for 103-1240-0020_16000Hz.wav: ['bored', 'with', 'wild', 'rose', 'bushes', 'it', "'s", 'no', 'wonder', 'Matthew', 'and', 'Marilla', 'are', 'both', 'a', 'little', 'odd', 'living', 'a', 'way', 'back', 'here', 'by', 'themselves', 'trees', 'are', "n't", 'much', 'company', 'though', 'dear', 'knows', 'if', 'they', 'were', 'there', "'d", 'be', 'enough', 'of', 'them', 'I', "'d", 'rather', 'look', 'at', 'people', 'to', 'be', 'sure', 'what']
# POS Tags for 103-1240-0020_16000Hz.wav: [('bored', 'VERB'), ('with', 'ADP'), ('wild', 'ADJ'), ('rose', 'VERB'), ('bushes', 'NOUN'), ('it', 'PRON'), ("'s", 'AUX'), ('no', 'DET'), ('wonder', 'NOUN'), ('Matthew', 'PROPN'), ('and', 'CCONJ'), ('Marilla', 'PROPN'), ('are', 'AUX'), ('both', 'PRON'), ('a', 'DET'), ('little', 'ADJ'), ('odd', 'ADJ'), ('living', 'NOUN'), ('a', 'DET'), ('way', 'NOUN'), ('back', 'ADV'), ('here', 'ADV'), ('by', 'ADP'), ('themselves', 'PRON'), ('trees', 'NOUN'), ('are', 'AUX'), ("n't", 'PART'), ('much', 'ADJ'), ('company', 'NOUN'), ('though', 'SCONJ'), ('dear', 'PROPN'), ('knows', 'VERB'), ('if', 'SCONJ'), ('they', 'PRON'), ('were', 'AUX'), ('there', 'PRON'), ("'d", 'AUX'), ('be', 'AUX'), ('enough', 'ADJ'), ('of', 'ADP'), ('them', 'PRON'), ('I', 'PRON'), ("'d", 'AUX'), ('rather', 'ADV'), ('look', 'VERB'), ('at', 'ADP'), ('people', 'NOUN'), ('to', 'PART'), ('be', 'AUX'), ('sure', 'ADJ'), ('what', 'PRON')]
# Entities for 103-1240-0020_16000Hz.wav: [('Matthew', 'PERSON'), ('Marilla', 'PERSON')]
# Full Transcription from all files: they couldn't break him of it if you had asked my advice in the matter which you didn't do Marilla I'd have said for Mercy sick not to think of such a thing that's what but there was a saving something about her mouth which if it had been ever so slightly developed might have been considered indicative of a sense of humor we're all pretty well said Mrs Rachel I was kind of afraid you weren't though when I saw Matthew starting off today I thought maybe he was going to the doctors for not even a Brooke could run past Mrs Rachel Lynn's door without due regard for decency and decorum it probably was conscious that Mrs Rachel was sitting at her window keeping a sharp eye on everything that passed from Brooks and children up at it does really seem as if I must be dreaming while I'm sorry for that poor young one and no mistake Matthew and Marilla don't know anything about children and they'll expect him to be wiser and steadier than his own grandfather what are marula and Matthew Cuthbert of all people adopting a boy from an orphan Asylum well the world was certainly turning upside down she would be surprised at nothing after this nothing at Mrs Alexander Spencer was up here one day before Christmas and she said she was going to get a little girl from the Asylum over in hopeton in the spring once you got a glimpse of the bloom white cherry trees in the left Orchard and nodding slender Birches down in the hollow by the Brook was screened over by a tangle of vines here satire Cuthbert when she sat at all always slightly distrustful of sunshine at what time are you going or would have been cheerful if it did not been so painfully clean as to give it something of the appearance of an unused parlor its Windows looked east and west through the West one looking out on the backyard came a flood of mellow June sunlight but the East one goes up at why it was only last week I read in the paper how a man and his wife up west of the island took a boy out of an orphan Asylum and he said fire to the house at night set it on purpose marila and nearly burned them to a crisp in their beds at if you run out of turnip seed he wouldn't dress up and take the buggy to go for more reasons set about on one side with great patriarchal Willows and the other with primates not a stray stick nor Stone was to be seen for Mrs Rachel would have seen it if there had been privately she was of the opinion that Marilla Cuthbert swept that yard over as often as she swept her house what get something must have happened since last night to start him off I'm clean puzzle that's what and I won't know a minute's peace of mind or conscience until I know what has taken Matthew Cuthbert out of heavenly today accordingly after tea Mrs Rachel set out she had not far to go to barely visible from the main road along which all the other avonley houses were so socially situated Mrs Rachel Lynde did not call living in such a place living at all it's just staying that's what she said if she stepped along the Deep rutted grassy Lane at Peter had asked him of course for Matthew Cuthbert had never been known to volunteer information about anything in his whole life and yet here was Matthew Cuthbert at half past 3:00 on the afternoon of a busy day plastically driving over the hollow and up the hill add Mrs Rachel dearly love to make a sensation so she took herself away someone to marilla's relief for the latter felt her doubts and fears Reviving under the influence of Mrs Rachel's pessimism well of all things that ever were or will be ejaculated Mrs Rachel when she was safely out in the Lane's what I anybody who went out of it or into it had to pass over that Hill Road and so run the Unseen Gauntlet of Mrs Rachel's All-Seeing Eye she was sitting there one afternoon in early June the sun was coming in at the window warm and bright start up at add here she sat now knitting and the table behind her was late for supper Mrs Rachel before she had Fairly closed t ...
